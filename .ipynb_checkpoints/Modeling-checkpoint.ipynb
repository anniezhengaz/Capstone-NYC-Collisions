# %%
#Import necessary functions
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

from datetime import datetime as dt

# %matplotlib inline

# %%
#Read in CSV and assign DateTime Index
df = pd.read_csv('data/Final_Motor_Vehicle_Collisions_QuBr_2018-2023.csv', index_col='CRASH DATE TIME', parse_dates=True)
df.head()
# Out:
#                      Unnamed: 0  COLLISION_ID   BOROUGH  ZIP CODE   LATITUDE  \
# CRASH DATE TIME
# 2018-01-01 00:00:00           1       3820945  BROOKLYN     11234  40.628770
# 2018-01-01 00:48:00          12       3821048  BROOKLYN     11203  40.639260
# 2018-01-01 01:30:00          21       3819375    QUEENS     11101  40.740913
# 2018-01-01 01:55:00          25       3821031  BROOKLYN     11226  40.652412
# 2018-01-01 02:29:00          31       3820976    QUEENS     11418  40.694690
#
#                      LONGITUDE  NUMBER OF PERSONS INJURED  \
# CRASH DATE TIME
# 2018-01-01 00:00:00  -73.91825                          1
# 2018-01-01 00:48:00  -73.93777                          0
# 2018-01-01 01:30:00  -73.95226                          0
# 2018-01-01 01:55:00  -73.95396                          0
# 2018-01-01 02:29:00  -73.83505                          2
#
#                      NUMBER OF PERSONS KILLED  \
# CRASH DATE TIME
# 2018-01-01 00:00:00                         0
# 2018-01-01 00:48:00                         0
# 2018-01-01 01:30:00                         0
# 2018-01-01 01:55:00                         0
# 2018-01-01 02:29:00                         0
#
#                                    CONTRIBUTING FACTOR VEHICLE 1  \
# CRASH DATE TIME
# 2018-01-01 00:00:00                Failure to Yield Right-of-Way
# 2018-01-01 00:48:00  Traffic Control Device Improper/Non-Working
# 2018-01-01 01:30:00                        Following Too Closely
# 2018-01-01 01:55:00               Driver Inattention/Distraction
# 2018-01-01 02:29:00                              Other Vehicular
#
#                                    CONTRIBUTING FACTOR VEHICLE 2  \
# CRASH DATE TIME
# 2018-01-01 00:00:00               Passing or Lane Usage Improper
# 2018-01-01 00:48:00  Traffic Control Device Improper/Non-Working
# 2018-01-01 01:30:00                        Following Too Closely
# 2018-01-01 01:55:00               Driver Inattention/Distraction
# 2018-01-01 02:29:00                        Following Too Closely
#
#                     CONTRIBUTING CATEGORY V1 CONTRIBUTING CATEGORY V2
# CRASH DATE TIME
# 2018-01-01 00:00:00         Moving Violation         Moving Violation
# 2018-01-01 00:48:00          Road Conditions          Road Conditions
# 2018-01-01 01:30:00         Moving Violation         Moving Violation
# 2018-01-01 01:55:00             Driver Error             Driver Error
# 2018-01-01 02:29:00  Third-Party (Vehicular)         Moving Violation

# %% [markdown]
# ## Train Test Split

# %%
#Find the index which allows us to split off 20% of the data
cutoff = round(df.shape[0]*0.8) #cut off point at 80% of the data
cutoff
# Out:
# 25517

# %%
# Define train and test sets according to the index found above
train = queens_ts[:cutoff] #before cut off is train set -- 80%

test = queens_ts[cutoff:] #after cut off is the test set --20%

fig, ax = plt.subplots(figsize=(12, 8))
ax.plot(train, label='train')
ax.plot(test, label='test')
ax.set_title('Train-Test Split');
plt.legend();
